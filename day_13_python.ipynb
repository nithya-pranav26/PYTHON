# %%
#Day– Dictionary, Set, Frozenset
#Project Title: Student Grades & Hobbies Tracker


# 1. Create a dictionary with student names and their grades
student_grades = {
    "kathir": 85,
    "thanish": 90,
    "suganth": 78
}

# %%
# 2. Allow the user to add or update grades for at least 3 students
print("Update/Add Grades for Students")

for i in range(3):
    name = input(f"Enter student name {i+1}: ")
    grade = int(input(f"Enter grade for {name}: "))
    student_grades[name] = grade   # adds new or updates existing
# Out:
# Update/Add Grades for Students
# Enter student name 1: nithi
# Enter grade for nithi: 90
# Enter student name 2: ram
# Enter grade for ram: 95
# Enter student name 3: seenu
# Enter grade for seenu: 100

# %%
# Display updated dictionary
print("\nUpdated Student Grades:")
for name, grade in student_grades.items():
    print(name, "-", grade)
# Out:
# Updated Student Grades:
# kathir - 85
# thanish - 90
# suganth - 78
# nithi - 90
# ram - 95
# seenu - 100

# %%
# 3. Create a set of hobbies and allow the user to input at least 3 hobbies
hobbies = set()
print("\nEnter 3 hobbies:")

for i in range(3):
    hobby = input(f"Hobby {i+1}: ")
    hobbies.add(hobby)
# Out:
# Enter 3 hobbies:
# Hobby 1: reading
# Hobby 2: watching tv
# Hobby 3: music

# %%
# 4. Convert the set into a frozenset
frozen_hobbies = frozenset(hobbies)


# Display results
print("\nHobbies (Set):", hobbies)
print("Hobbies (FrozenSet):", frozen_hobbies)
# Out:
# Hobbies (Set): {'music', 'watching tv', 'reading'}
# Hobbies (FrozenSet): frozenset({'music', 'watching tv', 'reading'})
